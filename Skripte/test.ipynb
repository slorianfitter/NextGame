# %%
import pandas as pd
from functions.Basemodell_v1 import base_recommend

# %%
df = pd.read_excel("D:/Projekte/spielvorschlag/data/eigene_daten.xlsx")

# %%
base = base_recommend(df)

# %%
base
# Out:
#                                        name    released  \
# 80941               Bling: Fortune Memories  2025-07-01
# 21682  The Legend of Eldridge Scrolls: Woop  2020-07-01
# 9729                       Signals of Chaos  2022-04-21
# 41595                        Hungry Zombies  2022-03-12
# 12685                      The Great Escape  2018-04-13
# 85709                     Karl The Good Man  2025-09-28
# 76878                           Disseminate  2024-12-08
# 71758                             FlyKnight  2025-01-31
# 13130                  Chicken ~Boiled Egg~  2018-05-18
# 62227                           Get To Work  2024-12-02
#
#        price_in_cents_no_discount  \
# 80941                         0.0
# 21682                        79.0
# 9729                        329.0
# 41595                       399.0
# 12685                       399.0
# 85709                       499.0
# 76878                       589.0
# 71758                       595.0
# ...
